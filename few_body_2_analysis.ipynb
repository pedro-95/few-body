# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from numpy.random import seed
from numpy.random import rand
import pylab 
import scipy.stats as stats

from matplotlib import rc
plt.rcParams.update({'font.size': 22})

# %%
# %load_ext autoreload

# %%
# %autoreload 1

# %%
# %aimport Block_Boostrap

# %%
from Block_Boostrap import SimpleBlockBootstrap
from Block_Boostrap import Bootstrap
from Block_Boostrap import DataBlocking
from Block_Boostrap import Autocorrelation, AutocorrelationNormalized

# %%
var_holder = {}
 
for i in range(19):
    var_holder['landa_' + str(i+1)] = np.loadtxt("samples/landa_" + str(i+1))
 
locals().update(var_holder)

# %%
var_holder_1 = {}
var_holder_2 = {}
 
for i in range(19):
    var_holder_1['landa_mean_' + str(i+1)], var_holder_2['landa_error_' + str(i+1)] = SimpleBlockBootstrap(var_holder['landa_' + str(i+1)])
    print ('landa_' + str(i+1), end="\r")
    
 
locals().update(var_holder_1)
locals().update(var_holder_2)
# Out:
# landa_19

# %% [markdown]
# # Triton Problem

# %%
print ("For our value of landa_1  = ", round(landa_mean_1,4), "+-", round(landa_error_1,4), " in the paper they obtain: 3.17     =>   ratio = ", round(3.17 / landa_mean_1, 3) )
print ("For our value of landa_2  = ", round(landa_mean_2,4), "+-", round(landa_error_2,4), " in the paper they obtain: 2.49     =>   ratio = ", round(2.49 / landa_mean_2, 3) )
print ("For our value of landa_3  = ", round(landa_mean_3,4), "+-", round(landa_error_3,4), " in the paper they obtain: 1.71     =>   ratio = ", round(1.71 / landa_mean_3, 3) )
print ("For our value of landa_4  = ", round(landa_mean_4,4), "+-", round(landa_error_4,4), " in the paper they obtain: 6.60     =>   ratio = ", round(6.60 / landa_mean_4, 3) )
print ("For our value of landa_5  = ", round(landa_mean_5,4), "+-", round(landa_error_5,4), " in the paper they obtain: 5.44     =>   ratio = ", round(5.44 / landa_mean_5, 3) )
print ("For our value of landa_6  = ", round(landa_mean_6,4), "+-", round(landa_error_6,4), " in the paper they obtain: 3.67     =>   ratio = ", round(3.67 / landa_mean_6, 3) )
print ("For our value of landa_7 = ",  round(landa_mean_7,4), "+-", round(landa_error_7,4), " in the paper they obtain: 17.5     =>   ratio = ", round(17.5 / landa_mean_7, 3) )
print ("For our value of landa_8  = ", round(landa_mean_8,4), "+-", round(landa_error_8,4), " in the paper they obtain: 11.6     =>   ratio = ", round(11.6 / landa_mean_8, 3) )
print ("For our value of landa_9  = ", round(landa_mean_9,4), "+-", round(landa_error_9,4), " in the paper they obtain: 6.09     =>   ratio = ", round(6.09 / landa_mean_9, 3) )
print ("For our value of landa_10 = ", round(landa_mean_10,4),"+-", round(landa_error_10,4), " in the paper they obtain: 4.30     =>   ratio = ", round(4.3 / landa_mean_10, 3) )
# Out:
# For our value of landa_1  =  3.0961 +- 0.0027  in the paper they obtain: 3.17     =>   ratio =  1.024
# For our value of landa_2  =  2.5124 +- 0.0023  in the paper they obtain: 2.49     =>   ratio =  0.991
# For our value of landa_3  =  1.7275 +- 0.0012  in the paper they obtain: 1.71     =>   ratio =  0.99
# For our value of landa_4  =  6.7391 +- 0.0068  in the paper they obtain: 6.60     =>   ratio =  0.979
# For our value of landa_5  =  5.4296 +- 0.0064  in the paper they obtain: 5.44     =>   ratio =  1.002
# For our value of landa_6  =  3.6915 +- 0.002  in the paper they obtain: 3.67     =>   ratio =  0.994
# For our value of landa_7 =  17.0077 +- 0.0196  in the paper they obtain: 17.5     =>   ratio =  1.029
# For our value of landa_8  =  11.3636 +- 0.0139  in the paper they obtain: 11.6     =>   ratio =  1.021
# For our value of landa_9  =  6.2546 +- 0.0065  in the paper they obtain: 6.09     =>   ratio =  0.974
# ...

# %% [markdown]
# # Alpha Problem

# %%
print ("For our value of landa_11 = ", round(landa_mean_11,4),"+-", round(landa_error_11,4), " in the paper they obtain: 1.17     =>   ratio = ", round(1.17 / landa_mean_11, 3) )
print ("For our value of landa_12 = ", round(landa_mean_12,4),"+-", round(landa_error_12,4), " in the paper they obtain: 0.67     =>   ratio = ", round(0.67 / landa_mean_12, 3) )
print ("For our value of landa_13 = ", round(landa_mean_13,4),"+-", round(landa_error_13,4), " in the paper they obtain: 0.48     =>   ratio = ", round(0.48 / landa_mean_13, 3) )
print ("For our value of landa_14 = ", round(landa_mean_14,4),"+-", round(landa_error_14,4), " in the paper they obtain: 2.55     =>   ratio = ", round(2.55 / landa_mean_14, 3) )
print ("For our value of landa_15 = ", round(landa_mean_15,4),"+-", round(landa_error_15,4), " in the paper they obtain: 1.40     =>   ratio = ", round(1.40 / landa_mean_15, 3) )
print ("For our value of landa_16 = ", round(landa_mean_16,4),"+-", round(landa_error_16,4), " in the paper they obtain: 0.97     =>   ratio = ", round(0.97 / landa_mean_16, 3) )
print ("For our value of landa_17 = ", round(landa_mean_17,4),"+-", round(landa_error_17,4), " in the paper they obtain: 9.00     =>   ratio = ", round(9.00 / landa_mean_17, 3) )
print ("For our value of landa_18 = ", round(landa_mean_18,4),"+-", round(landa_error_18,4), " in the paper they obtain: 4.27     =>   ratio = ", round(4.27 / landa_mean_18, 3) )
print ("For our value of landa_19 = ", round(landa_mean_19,4),"+-", round(landa_error_19,4), " in the paper they obtain: 2.94     =>   ratio = ", round(2.94 / landa_mean_19, 3) )
# Out:
# For our value of landa_11 =  1.1673 +- 0.0008  in the paper they obtain: 1.17     =>   ratio =  1.002
# For our value of landa_12 =  0.6661 +- 0.0004  in the paper they obtain: 0.67     =>   ratio =  1.006
# For our value of landa_13 =  0.4751 +- 0.0002  in the paper they obtain: 0.48     =>   ratio =  1.01
# For our value of landa_14 =  2.529 +- 0.0029  in the paper they obtain: 2.55     =>   ratio =  1.008
# For our value of landa_15 =  1.3982 +- 0.0009  in the paper they obtain: 1.40     =>   ratio =  1.001
# For our value of landa_16 =  0.9644 +- 0.0005  in the paper they obtain: 0.97     =>   ratio =  1.006
# For our value of landa_17 =  7.9648 +- 0.0132  in the paper they obtain: 9.00     =>   ratio =  1.13
# For our value of landa_18 =  4.2335 +- 0.0059  in the paper they obtain: 4.27     =>   ratio =  1.009
# For our value of landa_19 =  2.8141 +- 0.0028  in the paper they obtain: 2.94     =>   ratio =  1.045

# %% [markdown]
# # Deuteron Problem

# %%
def AnaliticalSolution(landa, A):
    return (np.pi/2 + np.arctan(1/np.sqrt(landa - 1)))/(A*np.sqrt(landa-1))

# %%
N = 2                                  # Number of Nuclei Particles
B_d = 2.226                            # Binding energy of the Deuteron in MeV
c = 2.998e+10                          # Speed of Light in cm/s
M = 938.272081                         # Mass of Proton in MeV/c²
hbar = 6.5821196e-22                   # h bar constant in MeV*s
R_d = hbar / (2*(M/c**2)*B_d)**(1/2)   # Unit of length in cm
A =  R_d/(hbar/np.sqrt(M*B_d/(c)**2))

# %%
ini = 20-1
end = 35

var_holder = {}
 
for i in range(ini,end):
    var_holder['landa_' + str(i+1)] = np.loadtxt("samples/landa_" + str(i+1))
 
locals().update(var_holder)

# %%
landa_deut_mean  = np.zeros(end-ini)
landa_deut_error = np.zeros(end-ini)
j=0

for i in range(ini,end):
    landa_deut_mean[j], landa_deut_error[j] = SimpleBlockBootstrap(var_holder['landa_' + str(i+1)])
    j+=1
    print ('landa_' + str(i+1), end="\r")
# Out:
# landa_35

# %%
landa = np.linspace(3, 20., 10000)
b = AnaliticalSolution(landa,A)

b_deut = np.arange(0.6,2.2,0.1)


rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)
plt.rcParams.update({'font.size': 22})

plt.figure(figsize=(10,10))
plt.plot(b, landa, label = "Analytical solution of the Deuteron (N = 2)")
plt.errorbar(b_deut,landa_deut_mean, yerr=landa_deut_error,fmt="ro", ecolor = "k", label = "Montecarlo integration")
plt.xlabel(r"$b/R_d$")
plt.ylabel(r"$V_{0} / B_d$")
plt.legend()
plt.savefig("plots/Deuteron.pdf", bbox_inches="tight")
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------------------------------

# %%
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

# %% [markdown]
# # Triton Plot Integration

# %%
b = np.array((1.35,1.5477,2.,2.5,3.,3.5,4.,4.5))

# %% [markdown]
# ## Squared Well

# %%
var_holder = {}
 
for i in range(8):
    var_holder['landa_squared_' + str(i+1)] = np.loadtxt("samples/triton_plot_squared_" + str(i+1))
 
locals().update(var_holder)

# %%
landa_trit_squared_mean  = np.zeros(8)
landa_trit_squared_error = np.zeros(8)

for i in range(8):
    landa_trit_squared_mean[i], landa_trit_squared_error[i] = SimpleBlockBootstrap(var_holder['landa_squared_' + str(i+1)])
    print ('landa_' + str(i+1), end="\r")
# Out:
# landa_8

# %%
plt.figure(figsize=(20,10))
plt.errorbar(b , landa_trit_squared_mean , yerr=landa_trit_squared_error, fmt="bo-", ecolor = "k" , label = "Squared Well")
plt.xlabel(r"$b/R_t$")
plt.ylabel(r"$V_{0} / B_t$")
plt.legend()
plt.savefig("plots/Triton_squared.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Gaussian Well

# %%
var_holder = {}
 
for i in range(8):
    var_holder['landa_gaussian_' + str(i+1)] = np.loadtxt("samples/triton_plot_gaussian_" + str(i+1))
 
locals().update(var_holder)

# %%
landa_trit_gaussian_mean  = np.zeros(8)
landa_trit_gaussian_error = np.zeros(8)

for i in range(8):
    landa_trit_gaussian_mean[i], landa_trit_gaussian_error[i] = SimpleBlockBootstrap(var_holder['landa_gaussian_' + str(i+1)])
    print ('landa_' + str(i+1), end="\r")
# Out:
# landa_8

# %%
plt.figure(figsize=(20,10))
plt.errorbar(b , landa_trit_gaussian_mean , yerr=landa_trit_gaussian_error, fmt="go-" ,ecolor = "k",  label = "Gaussian Well")
plt.xlabel(r"$b/R_t$")
plt.ylabel(r"$V_{0} / B_t$")
plt.legend()
plt.savefig("plots/Triton_gaussian.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Exponential Well

# %%
var_holder = {}
 
for i in range(8):
    var_holder['landa_exponential_' + str(i+1)] = np.loadtxt("samples/triton_plot_exponential_" + str(i+1))
 
locals().update(var_holder)

# %%
landa_trit_exponential_mean  = np.zeros(8)
landa_trit_exponential_error = np.zeros(8)

for i in range(8):
    landa_trit_exponential_mean[i], landa_trit_exponential_error[i] = SimpleBlockBootstrap(var_holder['landa_exponential_' + str(i+1)])
    print ('landa_' + str(i+1), end="\r")
# Out:
# landa_8

# %%
plt.figure(figsize=(20,10))
plt.errorbar(b , landa_trit_exponential_mean , yerr=landa_trit_exponential_error, fmt="ro-" ,ecolor = "k", label = "Exponential Well")
plt.xlabel(r"$b/R_t$")
plt.ylabel(r"$V_{0} / B_t$")
plt.legend()
plt.savefig("plots/Triton_exponential.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Total Plot

# %%
plt.figure(figsize=(10,20))
plt.errorbar(b , landa_trit_squared_mean , yerr=landa_trit_squared_error, fmt="bo--", ecolor = "k" , label = "Squared Well")
plt.errorbar(b , landa_trit_gaussian_mean , yerr=landa_trit_gaussian_error, fmt="go--" ,ecolor = "k",  label = "Gaussian Well")
plt.errorbar(b , landa_trit_exponential_mean , yerr=landa_trit_exponential_error, fmt="ro--" ,ecolor = "k", label = "Exponential Well")
plt.xlabel(r"$b/R_t$")
plt.ylabel(r"$V_{0} / B_t$")
plt.legend()
plt.savefig("plots/Triton_all.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Alpha Plot Integration

# %% [markdown]
# ## Squared Well

# %%
var_holder = {}
 
for i in range(8):
    var_holder['landa_alpha_squared_' + str(i+1)] = np.loadtxt("samples/alpha_plot_squared_" + str(i+1))
 
locals().update(var_holder)

# %%
landa_alph_squared_mean  = np.zeros(8)
landa_alph_squared_error = np.zeros(8)

for i in range(8):
    landa_alph_squared_mean[i], landa_alph_squared_error[i] = SimpleBlockBootstrap(var_holder['landa_alpha_squared_' + str(i+1)])
    print ('landa_' + str(i+1), end="\r")
# Out:
# landa_8

# %%
plt.figure(figsize=(20,10))
plt.errorbar(b , landa_alph_squared_mean , yerr=landa_alph_squared_error, fmt="bo-", ecolor = "k" , label = "Squared Well")
plt.xlabel(r"$b/R_{\alpha}$")
plt.ylabel(r"$V_{0} / B_{\alpha}$")
plt.legend()
plt.savefig("plots/Alpha_squared.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Gaussian Well

# %%
var_holder = {}
 
for i in range(8):
    var_holder['landa_alpha_gaussian_' + str(i+1)] = np.loadtxt("samples/alpha_plot_gaussian_" + str(i+1))
 
locals().update(var_holder)

# %%
landa_alph_gaussian_mean  = np.zeros(8)
landa_alph_gaussian_error = np.zeros(8)

for i in range(8):
    landa_alph_gaussian_mean[i], landa_alph_gaussian_error[i] = SimpleBlockBootstrap(var_holder['landa_alpha_gaussian_' + str(i+1)])
    print ('landa_' + str(i+1), end="\r")
# Out:
# landa_8

# %%
plt.figure(figsize=(20,10))
plt.errorbar(b , landa_alph_gaussian_mean , yerr=landa_alph_gaussian_error, fmt="go-" ,ecolor = "k",  label = "Gaussian Well")
plt.xlabel(r"$b/R_{\alpha}$")
plt.ylabel(r"$V_{0} / B_{\alpha}$")
plt.legend()
plt.savefig("plots/Alpha_gaussian.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Exponential Well

# %%
var_holder = {}
 
for i in range(8):
    var_holder['landa_alpha_exponential_' + str(i+1)] = np.loadtxt("samples/alpha_plot_exponential_" + str(i+1))
 
locals().update(var_holder)

# %%
landa_alph_exponential_mean  = np.zeros(8)
landa_alph_exponential_error = np.zeros(8)

for i in range(8):
    landa_alph_exponential_mean[i], landa_alph_exponential_error[i] = SimpleBlockBootstrap(var_holder['landa_alpha_exponential_' + str(i+1)])
    print ('landa_' + str(i+1), end="\r")
# Out:
# landa_8

# %%
plt.figure(figsize=(20,10))
plt.errorbar(b , landa_alph_exponential_mean , yerr=landa_alph_exponential_error, fmt="bo-" ,ecolor = "k", label = "Exponential Well")
plt.xlabel(r"$b/R_{\alpha}$")
plt.ylabel(r"$V_{0} / B_{\alpha}$")
plt.legend()
plt.savefig("plots/Alpha_exponential.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Total Plot

# %%
plt.figure(figsize=(10,20))
plt.errorbar(b , landa_alph_squared_mean , yerr=landa_alph_squared_error, fmt="bo--", ecolor = "k" , label = "Squared Well")
plt.errorbar(b , landa_alph_gaussian_mean , yerr=landa_alph_gaussian_error, fmt="go--" ,ecolor = "k",  label = "Gaussian Well")
plt.errorbar(b , landa_alph_exponential_mean , yerr=landa_alph_exponential_error, fmt="ro--" ,ecolor = "k", label = "Exponential Well")
plt.xlabel(r"$b/R_{\alpha}$")
plt.ylabel(r"$V_{0} / B_{\alpha}$")
plt.legend()
plt.savefig("plots/Alpha_all.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Plot of Wells

# %%
plt.figure(figsize=(10,20))
plt.title("Squared Well")
plt.errorbar(b , landa_trit_squared_mean , yerr=landa_trit_squared_error, fmt="bo--", ecolor = "k" , label = "Triton")
plt.errorbar(b , landa_alph_squared_mean , yerr=landa_alph_squared_error, fmt="go--" ,ecolor = "k",  label = "Alpha Particle")
plt.xlabel(r"$b/R$")
plt.ylabel(r"$V_{0} / B$")
plt.legend()
plt.savefig("plots/Squared_Well.pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10,20))
plt.title("Gaussian Well")
plt.errorbar(b , landa_trit_gaussian_mean , yerr=landa_trit_gaussian_error, fmt="bo--", ecolor = "k" , label = "Triton")
plt.errorbar(b , landa_alph_gaussian_mean , yerr=landa_alph_gaussian_error, fmt="go--" ,ecolor = "k",  label = "Alpha Particle")
plt.xlabel(r"$b/R$")
plt.ylabel(r"$V_{0} / B$")
plt.legend()
plt.savefig("plots/Gaussian_Well.pdf", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10,20))
plt.title("Exponential Well")
plt.errorbar(b , landa_trit_exponential_mean , yerr=landa_trit_exponential_error, fmt="bo--", ecolor = "k" , label = "Triton")
plt.errorbar(b , landa_alph_exponential_mean , yerr=landa_alph_exponential_error, fmt="go--" ,ecolor = "k",  label = "Alpha Particle")
plt.xlabel(r"$b/R$")
plt.ylabel(r"$V_{0} / B$")
plt.legend()
plt.savefig("plots/Exponential_Well.pdf", bbox_inches="tight")
plt.show()

# %%
plt.rcParams.update({'font.size': 30})
fig = plt.figure(figsize=(30,20))

ax1 = plt.subplot (1,3,1)
plt.title("Squared Well")
plt.xlabel(r"$b/R$")
plt.ylabel(r"$V_{0} / B$")
ax1.errorbar(b , landa_trit_squared_mean , yerr=landa_trit_squared_error, fmt="bo--", ecolor = "k" , label = "Triton")
ax1.errorbar(b , landa_alph_squared_mean , yerr=landa_alph_squared_error, fmt="go--" ,ecolor = "k",  label = "Alpha Particle")
plt.legend()

ax2 = plt.subplot (1,3,2)
plt.title("Gaussian Well")
plt.xlabel(r"$b/R$")
plt.ylabel(r"$V_{0} / B$")
ax2.errorbar(b , landa_trit_gaussian_mean , yerr=landa_trit_gaussian_error, fmt="bo--", ecolor = "k" , label = "Triton")
ax2.errorbar(b , landa_alph_gaussian_mean , yerr=landa_alph_gaussian_error, fmt="go--" ,ecolor = "k",  label = "Alpha Particle")
plt.legend()

ax3 = plt.subplot (1,3,3)
plt.title("Exponential Well")
plt.xlabel(r"$b/R$")
plt.ylabel(r"$V_{0} / B$")
ax3.errorbar(b , landa_trit_exponential_mean , yerr=landa_trit_exponential_error, fmt="bo--", ecolor = "k" , label = "Triton")
ax3.errorbar(b , landa_alph_exponential_mean , yerr=landa_alph_exponential_error, fmt="go--" ,ecolor = "k",  label = "Alpha Particle")
plt.legend()

plt.savefig("plots/All_Wells.pdf", bbox_inches="tight")
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
plt.rcParams.update({'font.size': 30})
fig = plt.figure(figsize=(20,15))

ax1 = plt.subplot (1,2,1)
plt.title("Triton")
plt.xlabel(r"$b/R_t$")
plt.ylabel(r"$V_{0} / B_t$")
plt.yticks(np.arange(0., max(landa_trit_exponential_mean)+1., 1.0))
plt.xticks(np.arange(1, max(b)+1, 0.5))
plt.ylim(0, 22)
ax1.errorbar(b , landa_trit_squared_mean , yerr=landa_trit_squared_error, fmt="bo--", ecolor = "k" , label = "Squared Well")
ax1.errorbar(b , landa_trit_gaussian_mean , yerr=landa_trit_gaussian_error, fmt="go--" ,ecolor = "k",  label = "Gaussian Well")
ax1.errorbar(b , landa_trit_exponential_mean , yerr=landa_trit_exponential_error, fmt="ro--" ,ecolor = "k", label = "Exponential Well")
plt.grid(True)
plt.legend()


ax2 = plt.subplot (1,2,2)
plt.title("Alpha Particle")
plt.xlabel(r"$b/R_{\alpha}$")
plt.ylabel(r"$V_{0} / B_{\alpha}$")
plt.ylim(0, 16)
plt.yticks(np.arange(0., max(landa_alph_exponential_mean)+1., 1.0))
plt.xticks(np.arange(1, max(b)+1, 0.5))
ax2.errorbar(b , landa_alph_squared_mean , yerr=landa_alph_squared_error, fmt="bo--", ecolor = "k" , label = "Squared Well")
ax2.errorbar(b , landa_alph_gaussian_mean , yerr=landa_alph_gaussian_error, fmt="go--" ,ecolor = "k",  label = "Gaussian Well")
ax2.errorbar(b , landa_alph_exponential_mean , yerr=landa_alph_exponential_error, fmt="ro--" ,ecolor = "k", label = "Exponential Well")
plt.grid(True)
plt.legend()

plt.savefig("plots/All.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------------------------------

# %%
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

# %% [markdown]
# # Wave Function

# %%
from few_body import GreenFunctionMonteCarlo
from few_body import SquaredWell
from few_body import GaussianWell
from few_body import ExponentialWell
from numpy.linalg import norm

# %%
def PointEstimator(R_m):
    L, = np.shape(R_m)
    N = int(L/3) 
    
    suma = 0.
    norma = 0.
    
    for i in range (0 , N):
        for j in range (i+1, N):
            suma += norm(R_m[3*i:3*(i+1)]-R_m[3*j:3*(j+1)])
            norma += 1.
    return suma/norma

def WaveFunctionEstimator(R):
    size, L = np.shape(R)
    wave = np.zeros(size)
    
    for i in range (0,size):
        wave[i] = PointEstimator(R[i])
        
    return wave

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes


def test_hist_2d(x_data, y_data, x_labels, y_labels, Name_of_the_particle, save_fig = False):
    nrows, ncols = 1, 3
    fig, axes = plt.subplots(nrows, ncols, sharex=True, sharey=True,constrained_layout=True, figsize = (30,10))
    
    fig.suptitle(Name_of_the_particle, fontsize=50)
    
    ##produce the actual data and compute the histograms
    mappables=[]
    for (i,), ax in np.ndenumerate(axes):
        H, xedges, yedges,image = plt.hist2d(x_data[i], y_data[i], bins=50, density=True , range=[[-20, 20],[-20, 20]])
        ax.set_xlabel(x_labels[i], fontsize =40)
        ax.set_ylabel(y_labels[i], fontsize =40)
        ax.set_aspect("equal")
        mappables.append(H)

    ##the min and max values of all histograms
    vmin = np.min(mappables)
    vmax = np.max(mappables)
    #vmax = 0.026
    
    ##second loop for visualisation
    for ax, H in zip(axes.ravel(), mappables):
        im = ax.imshow(H,vmin=vmin, vmax=vmax, extent=[-20,20,-20,20])#, cmap = "seismic"

    ##colorbar using solution from linked question
    axins = inset_axes(ax,
                    width="5%",  # width = 50% of parent_bbox width
                    height="100%",  # height : 5%
                    loc='upper right',
                    bbox_to_anchor=(0.2, 0.01, 1., 1),
                    bbox_transform=ax.transAxes,)

    
    fig.colorbar(im ,ax=axes.ravel(), cax = axins)
    
    if (save_fig == True):
        plt.savefig("plots/"+Name_of_the_particle+".pdf", bbox_inches="tight")
    plt.show()

# %%
N = 3                                  # Number of Nuclei Particles
b_r = 1.                               # Range parameter normalized to R: b_r = b / R (b_r has no units)
Niter = 100                            # Number of iterations in our calculation
landa_0 = 34  #squ:37, gauss:34 ,exp:120  # Initial parameter that must be high enough to increase the point number
Nthreshold = 8000                      # Threshold value for the number of R points to change landa_0 in the loop
output = 1                             # Do you want to see more of the integration? Then set to 1

R_1 = GreenFunctionMonteCarlo(N, GaussianWell, b_r, landa_0, Niter, Nthreshold, output, R_as_output = True)
# Out:
# i =  100   Size =  11696   Sum(W[i]) =  1063.0425785820676   =>  landa[i] =  11.002381499714371

# %%
N = 3                                  # Number of Nuclei Particles
b_r = 5.                               # Range parameter normalized to R: b_r = b / R (b_r has no units)
Niter = 100                            # Number of iterations in our calculation
landa_0 = 15  #squ:10, gauss:15 ,exp:100  # Initial parameter that must be high enough to increase the point number
Nthreshold = 8000                      # Threshold value for the number of R points to change landa_0 in the loop
output = 1                             # Do you want to see more of the integration? Then set to 1

R_2 = GreenFunctionMonteCarlo(N, GaussianWell, b_r, landa_0, Niter, Nthreshold, output, R_as_output = True)
# Out:
# i =  100   Size =  14663   Sum(W[i]) =  12263.647421369127   =>  landa[i] =  1.195647550536234

# %%
N = 3                                  # Number of Nuclei Particles
b_r = 10.                              # Range parameter normalized to R: b_r = b / R (b_r has no units)
Niter = 100                            # Number of iterations in our calculation
landa_0 = 11  #squ:9, gauss:11 ,exp:100  # Initial parameter that must be high enough to increase the point number
Nthreshold = 8000                      # Threshold value for the number of R points to change landa_0 in the loop
output = 1                             # Do you want to see more of the integration? Then set to 1

R_3 = GreenFunctionMonteCarlo(N, GaussianWell, b_r, landa_0, Niter, Nthreshold, output, R_as_output = True)
# Out:
# i =  100   Size =  13389   Sum(W[i]) =  19345.391410910786   =>  landa[i] =  0.6921028226106923

# %%
wave_1 = WaveFunctionEstimator(R_1)
wave_2 = WaveFunctionEstimator(R_2)
wave_3 = WaveFunctionEstimator(R_3)

# %%
N = 4                                  # Number of Nuclei Particles
b_r = 1.                               # Range parameter normalized to R: b_r = b / R (b_r has no units)
Niter = 100                            # Number of iterations in our calculation
landa_0 = 20   #squ:20, gauss:20 ,exp:70   # Initial parameter that must be high enough to increase the point number
Nthreshold = 8000                      # Threshold value for the number of R points to change landa_0 in the loop
output = 1                             # Do you want to see more of the integration? Then set to 1

R_4 = GreenFunctionMonteCarlo(N, GaussianWell, b_r, landa_0, Niter, Nthreshold, output, R_as_output = True)
# Out:
# i =  100   Size =  12790   Sum(W[i]) =  1555.867029515033   =>  landa[i] =  8.2204968402644724

# %%
N = 4                                  # Number of Nuclei Particles
b_r = 5.                               # Range parameter normalized to R: b_r = b / R (b_r has no units)
Niter = 100                            # Number of iterations in our calculation
landa_0 = 8 #squ:5, gauss:8 ,exp:60    # Initial parameter that must be high enough to increase the point number
Nthreshold = 8000                      # Threshold value for the number of R points to change landa_0 in the loop
output = 1                             # Do you want to see more of the integration? Then set to 1

R_5 = GreenFunctionMonteCarlo(N, GaussianWell, b_r, landa_0, Niter, Nthreshold, output, R_as_output = True)
# Out:
# i =  100   Size =  13249   Sum(W[i]) =  17865.077285571955   =>  landa[i] =  0.7416144799272739

# %%
N = 4                                  # Number of Nuclei Particles
b_r = 10.                              # Range parameter normalized to R: b_r = b / R (b_r has no units)
Niter = 100                            # Number of iterations in our calculation
landa_0 = 6 #squ:4, gauss:6 ,exp:50     # Initial parameter that must be high enough to increase the point number
Nthreshold = 8000                      # Threshold value for the number of R points to change landa_0 in the loop
output = 1                             # Do you want to see more of the integration? Then set to 1

R_6 = GreenFunctionMonteCarlo(N, GaussianWell, b_r, landa_0, Niter, Nthreshold, output, R_as_output = True)
# Out:
# i =  100   Size =  15614   Sum(W[i]) =  39580.17290616496   =>  landa[i] =  0.39449044442067064

# %%
wave_4 = WaveFunctionEstimator(R_4)
wave_5 = WaveFunctionEstimator(R_5)
wave_6 = WaveFunctionEstimator(R_6)

# %%
N = 2                                  # Number of Nuclei Particles
b_r = 1.                               # Range parameter normalized to R: b_r = b / R (b_r has no units)
Niter = 100                            # Number of iterations in our calculation
landa_0 = 60 #squ:50, gauss:60 ,exp:140    # Initial parameter that must be high enough to increase the point number
Nthreshold = 8000                      # Threshold value for the number of R points to change landa_0 in the loop
output = 1                             # Do you want to see more of the integration? Then set to 1

R_7 = GreenFunctionMonteCarlo(N, GaussianWell, b_r, landa_0, Niter, Nthreshold, output, R_as_output = True)
# Out:
# i =  100   Size =  11791   Sum(W[i]) =  649.8298229758863   =>  landa[i] =  18.14475049175688

# %%
N = 2                                  # Number of Nuclei Particles
b_r = 5.                               # Range parameter normalized to R: b_r = b / R (b_r has no units)
Niter = 100                            # Number of iterations in our calculation
landa_0 = 40  #squ:30, gauss:40 ,exp:70    # Initial parameter that must be high enough to increase the point number
Nthreshold = 8000                      # Threshold value for the number of R points to change landa_0 in the loop
output = 1                             # Do you want to see more of the integration? Then set to 1

R_8 = GreenFunctionMonteCarlo(N, GaussianWell, b_r, landa_0, Niter, Nthreshold, output, R_as_output = True)
# Out:
# i =  100   Size =  11870   Sum(W[i]) =  4428.182442056999   =>  landa[i] =  2.6805580292410207

# %%
N = 2                                  # Number of Nuclei Particles
b_r = 10.                              # Range parameter normalized to R: b_r = b / R (b_r has no units)
Niter = 100                            # Number of iterations in our calculation
landa_0 = 32 #squ:25, gauss:32 ,exp:50     # Initial parameter that must be high enough to increase the point number
Nthreshold = 8000                      # Threshold value for the number of R points to change landa_0 in the loop
output = 1                             # Do you want to see more of the integration? Then set to 1

R_9 = GreenFunctionMonteCarlo(N, GaussianWell, b_r, landa_0, Niter, Nthreshold, output, R_as_output = True)
# Out:
# i =  100   Size =  15526   Sum(W[i]) =  9099.489057150935   =>  landa[i] =  1.7062496479182774

# %%
wave_7 = WaveFunctionEstimator(R_7)
wave_8 = WaveFunctionEstimator(R_8)
wave_9 = WaveFunctionEstimator(R_9)

# %%
plt.rcParams.update({'font.size': 25})
plt.figure(figsize=(30,10))
plt.suptitle("Gaussian Well", fontsize=35)

plt.subplot(1,3,1)
plt.xlim(0, 17)
plt.ylim(0, 0.3)
plt.hist(wave_7, 100, density=True, facecolor='g', alpha =0.5, label = r"$b/R_d = 1.$")
plt.hist(wave_8, 100, density=True, facecolor='b', alpha =0.5, label = r"$b/R_d = 5.$")
plt.hist(wave_9, 100, density=True, facecolor='r', alpha =0.5, label = r"$b/R_d = 10.$")
plt.xlabel('Medium distance between particles')
plt.ylabel('Density of states')
plt.title('Deuteron')
plt.legend()

plt.subplot(1,3,2)
plt.xlim(0, 17)
plt.ylim(0, 0.3)
plt.hist(wave_1, 100, density=True, facecolor='g', alpha =0.5, label = r"$b/R_t = 1.$")
plt.hist(wave_2, 100, density=True, facecolor='b', alpha =0.5, label = r"$b/R_t = 5.$")
plt.hist(wave_3, 100, density=True, facecolor='r', alpha =0.5, label = r"$b/R_t = 10.$")
plt.xlabel('Medium distance between particles')
plt.title('Triton Particle')
plt.legend()


plt.subplot(1,3,3)
plt.xlim(0, 17)
plt.ylim(0, 0.3)
plt.hist(wave_4, 100, density=True, facecolor='g', alpha =0.5, label = r"$b/R_{\alpha} = 1.$")
plt.hist(wave_5, 100, density=True, facecolor='b', alpha =0.5, label = r"$b/R_{\alpha} = 5.$")
plt.hist(wave_6, 100, density=True, facecolor='r', alpha =0.5, label = r"$b/R_{\alpha} = 10.$")
plt.xlabel('Medium distance between particles')
plt.title('Alpha Particle')
plt.legend()
plt.savefig("plots/Medium Distance Gaussian.pdf", bbox_inches="tight")
plt.show()

# %%
from numpy.random import seed
from numpy.random import randint
import matplotlib.colors as mcolors
seed(0)

# %%
def DeuteronPointEstimator(R_m):
    L, = np.shape(R_m)
    N = int(L/3) 
    suma_1 = 0.
    suma_2 = 0.
    suma_3 = 0.
    norma = 0.
    for i in range (0 , N):
        for j in range (i+1, N):
            suma_1 += R_m[3*i]-R_m[3*j]
            suma_2 += R_m[3*i+1]-R_m[3*j+1]
            suma_3 += R_m[3*i+2]-R_m[3*j+2]
            norma+=1.
    return N*suma_1/norma, N*suma_2/norma, N*suma_3/norma

def DeuteronWaveFunctionEstimator(R):
    size, L = np.shape(R)
    wave = np.zeros((size,3))
    
    for i in range (0,size):
        wave[i] = DeuteronPointEstimator(R[i])
    return wave

# %%
R_10 = 1*R_8
R_11 = 1*R_2
R_12 = 1*R_5

# %%
wave_10 = DeuteronWaveFunctionEstimator(R_10)

# %%
data_x = [wave_10[:,0], wave_10[:,0],wave_10[:,1]]
data_y = [wave_10[:,1], wave_10[:,2],wave_10[:,2]]
x_labels = [r'$x_1 - x_2$', r'$x_1 - x_2$',r'$y_1 - y_2$']
y_labels = [r'$y_1 - y_2$', r'$z_1 - z_2$',r'$z_1 - z_2$']
plt.rcParams.update({'font.size': 30})
test_hist_2d(data_x, data_y, x_labels, y_labels, "Deuteron Wave Function: Gaussian Well", save_fig=True)

# %%
wave_11 = DeuteronWaveFunctionEstimator(R_11)

# %%
data_x = [wave_11[:,0], wave_11[:,0],wave_11[:,1]]
data_y = [wave_11[:,1], wave_11[:,2],wave_11[:,2]]
x_labels = [r'$x_n - x_m$', r'$x_n - x_m$',r'$y_n - y_m$']
y_labels = [r'$y_n - y_m$', r'$z_n - z_m$',r'$z_n - z_m$']
plt.rcParams.update({'font.size': 30})
test_hist_2d(data_x, data_y, x_labels, y_labels, "Triton Wave Function: Gaussian Well", save_fig=True)

# %%
wave_12 = DeuteronWaveFunctionEstimator(R_12)

# %%
data_x = [wave_12[:,0], wave_12[:,0],wave_12[:,1]]
data_y = [wave_12[:,1], wave_12[:,2],wave_12[:,2]]
x_labels = [r'$x_n - x_m$', r'$x_n - x_m$',r'$y_n - y_m$']
y_labels = [r'$y_n - y_m$', r'$z_n - z_m$',r'$z_n - z_m$']
plt.rcParams.update({'font.size': 30})
test_hist_2d(data_x, data_y, x_labels, y_labels, "Alpha Particle Wave Function: Gaussian Well", save_fig=True)

# %%
N = 2                                  # Number of Nuclei Particles
B_d = 2.226                            # Binding energy of the Deuteron in MeV
c = 2.998e+10                          # Speed of Light in cm/s
M = 938.272081                         # Mass of Proton in MeV/c²
hbar = 6.5821196e-22                   # h bar constant in MeV*s
R_d = hbar / (2*(M/c**2)*B_d)**(1/2)   # Unit of length in cm

# %%
N = 3                                  # Number of Nuclei Particles
B_t = 8.49                             # Binding energy of the Triton in MeV
c = 2.998e+10                          # Speed of Light in cm/s
M = 938.272081                         # Mass of Proton in MeV/c²
hbar = 6.5821196e-22                   # h bar constant in MeV*s
R_t = hbar / (2*(M/c**2)*B_t)**(1/2)   # Unit of length in cm

# %%
N = 4                                  # Number of Nuclei Particles
B_a = 28.3                             # Binding energy of the Alpha particle in MeV
c = 2.998e+10                          # Speed of Light in cm/s
M = 938.272081                         # Mass of Proton in MeV/c²
hbar = 6.5821196e-22                   # h bar constant in MeV*s
R_a = hbar / (2*(M/c**2)*B_a)**(1/2)   # Unit of length in m

# %%
print (R_d)
print (R_t)
print (R_a)
# Out:
# 3.053201191241964e-13
# 1.5633785824497803e-13
# 8.56297715528195e-14
